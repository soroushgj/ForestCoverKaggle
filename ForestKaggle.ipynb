# %%
import numpy as np 
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('/content/train.csv')
data.head()
# Out:
#    Id  Elevation  Aspect  ...  Soil_Type39  Soil_Type40  Cover_Type
# 0   1       2596      51  ...            0            0           5
# 1   2       2590      56  ...            0            0           5
# 2   3       2804     139  ...            0            0           2
# 3   4       2785     155  ...            0            0           2
# 4   5       2595      45  ...            0            0           5
#
# [5 rows x 56 columns]

# %%
data_full = data.copy()
X_data = data_full.drop('Cover_Type', axis=1)
X_data = X_data.drop('Id', axis=1)
y = data_full.Cover_Type
X_data.head()
# Out:
#    Elevation  Aspect  Slope  ...  Soil_Type38  Soil_Type39  Soil_Type40
# 0       2596      51      3  ...            0            0            0
# 1       2590      56      2  ...            0            0            0
# 2       2804     139      9  ...            0            0            0
# 3       2785     155     18  ...            0            0            0
# 4       2595      45      2  ...            0            0            0
#
# [5 rows x 54 columns]

# %%
#Split the dataset into train and Test

seed = 7
test_size = 0.3
X_trian, X_test, y_train, y_test = train_test_split(X_data, y, test_size=test_size, random_state=seed)

# %%
modelXGB = xgb.XGBClassifier(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)
train_modelXGB = modelXGB.fit(X_trian, y_train)

# %%
#prediction and Classification Report
from sklearn.metrics import classification_report

XGB_pred = train_modelXGB.predict(X_test)
print('Model XGboost Report %r' % (classification_report(y_test, XGB_pred)))
# Out:
# Model XGboost Report '              precision    recall  f1-score   support\n\n           1       0.76      0.70      0.73       644\n           2       0.73      0.64      0.68       630\n           3       0.87      0.79      0.83       671\n           4       0.94      0.98      0.96       634\n           5       0.85      0.95      0.90       661\n           6       0.82      0.88      0.85       666\n           7       0.92      0.97      0.94       630\n\n    accuracy                           0.85      4536\n   macro avg       0.84      0.84      0.84      4536\nweighted avg       0.84      0.85      0.84      4536\n'

# %%
#Let's use accuracy score
from sklearn.metrics import accuracy_score
print("Accuracy for model XGB: %.2f" % (accuracy_score(y_test, XGB_pred) * 100))
# Out:
# Accuracy for model XGB: 84.50

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc_model = rfc.fit(X_trian, y_train)
RFC_pred = rfc_model.predict(X_test)
print("Accuracy for Random Forest Model: %.2f" % (accuracy_score(y_test, RFC_pred) * 100))
# Out:
# Accuracy for Random Forest Model: 85.45

# %%
test_data_full = pd.read_csv('/content/test.csv')
test_data = test_data_full.drop('Id', axis=1)
test_data
finalPrediction = train_model2.predict(test_data)

# %%
RFCfinalprediction = rfc_model.predict(test_data)

# %%
finalPrediction
# Out:
# array([2, 2, 1, ..., 3, 3, 3])

# %%
RFCfinalprediction
# Out:
# array([2, 1, 2, ..., 3, 3, 3])

# %%
finalPrediction = pd.DataFrame(finalPrediction)
finalPrediction['Id'] = test_data_full['Id']
finalPrediction = finalPrediction.rename(columns={0 : 'Cover_Type', 'Id': 'Id'})
finalPrediction = finalPrediction[['Id', 'Cover_Type']]
finalPrediction
# Out:
#             Id  Cover_Type
# 0        15121           2
# 1        15122           2
# 2        15123           1
# 3        15124           1
# 4        15125           1
# ...        ...         ...
# 565887  581008           3
# 565888  581009           3
# 565889  581010           3
# 565890  581011           3
# 565891  581012           3
#
# [565892 rows x 2 columns]

# %%
RFCfinalprediction = pd.DataFrame(RFCfinalprediction)
RFCfinalprediction['Id'] = test_data_full['Id']
RFCfinalprediction = RFCfinalprediction.rename(columns={0 : 'Cover_Type', 'Id': 'Id'})
RFCfinalprediction = RFCfinalprediction[['Id', 'Cover_Type']]
RFCfinalprediction
# Out:
#             Id  Cover_Type
# 0        15121           2
# 1        15122           1
# 2        15123           2
# 3        15124           1
# 4        15125           1
# ...        ...         ...
# 565887  581008           3
# 565888  581009           3
# 565889  581010           3
# 565890  581011           3
# 565891  581012           3
#
# [565892 rows x 2 columns]

# %%
finalPrediction.to_csv('/content/finalprediction.csv', index=False)

# %%
RFCfinalprediction.to_csv('/content/RFCfinalprediction.csv', index=False)
